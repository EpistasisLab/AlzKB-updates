# %% [markdown]
# # Download
# https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/desc2024.gz
# or
# https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/desc2024.xml

# %%
#!wget --timestamping --directory-prefix download/ ftp://nlmpubs.nlm.nih.gov/online/mesh/.xmlmesh/desc2015.gz

# %%
import os
import gzip
import io
import json

import xml.etree.ElementTree as ET

import networkx
import pandas

# %%
download_dir ='../data/MeSH'

# %%
# Read MeSH xml release
#xml_path = '../data/desc2024.gz' #os.path.join('download', 'desc2015.gz')
#with gzip.open(xml_path) as xml_file:
#    tree = ET.parse(xml_file)
#root = tree.getroot()

xml_path = os.path.join(download_dir, 'desc2024.xml') 
tree = ET.parse(xml_path)
root = tree.getroot()

# %%
# Extract mesh terms
term_dicts = list()
for descriptor in root:
    for concept in descriptor.findall('ConceptList/Concept'):
        for term in concept.findall('TermList/Term'):
            term_dict = {
                'DescriptorUI': descriptor.findtext('DescriptorUI'),
                'ConceptUI': concept.findtext('ConceptUI'),
                'TermUI': term.findtext('TermUI'),
                'TermName': term.findtext('String')
            }
            term_dict.update(concept.attrib)
            term_dict.update(term.attrib)
            term_dicts.append(term_dict)

columns = ['DescriptorUI', 'ConceptUI', 'PreferredConceptYN', 'TermUI', 'TermName',
           'ConceptPreferredTermYN', 'IsPermutedTermYN', 'LexicalTag', 'RecordPreferredTermYN'] #, 'PrintFlagYN'
term_df = pandas.DataFrame(term_dicts)[columns]
term_df.to_csv(os.path.join(download_dir, 'descriptor-terms.tsv'), index=False, sep='\t')
term_df
# Out:
#        DescriptorUI ConceptUI PreferredConceptYN      TermUI  \
# 0           D000001  M0000001                  Y     T000002
# 1           D000001  M0000001                  Y  T001124965
# 2           D000001  M0353609                  N     T000001
# 3           D000001  M0353609                  N     T000001
# 4           D000001  M0353609                  N     T000004
# ...             ...       ...                ...         ...
# 263931      D066331  M0594254                  Y     T859704
# 263932      D066331  M0594254                  Y     T859704
# 263933      D066331  M0594254                  Y     T859704
# 263934      D066331  M0594254                  Y     T859704
# 263935      D066331  M0594254                  Y     T859704
#
#                                                  TermName  \
# 0                                              Calcimycin
# 1       4-Benzoxazolecarboxylic acid, 5-(methylamino)-...
# 2                                                 A-23187
# 3                                                 A 23187
# 4                                                  A23187
# ...                                                   ...
# 263931                            Laser-Evoked Potentials
# 263932                            Laser Evoked Potentials
# 263933                             Laser-Evoked Potential
# 263934                            Potential, Laser-Evoked
# 263935                           Potentials, Laser-Evoked
#
#        ConceptPreferredTermYN IsPermutedTermYN LexicalTag  \
# 0                           Y                N        NON
# 1                           N                N        NON
# 2                           Y                N        LAB
# 3                           N                Y        LAB
# 4                           N                N        LAB
# ...                       ...              ...        ...
# 263931                      Y                N        NON
# 263932                      N                Y        NON
# 263933                      N                Y        NON
# 263934                      N                Y        NON
# 263935                      N                Y        NON
#
#        RecordPreferredTermYN
# 0                          Y
# 1                          N
# 2                          N
# 3                          N
# 4                          N
# ...                      ...
# 263931                     Y
# 263932                     N
# 263933                     N
# 263934                     N
# 263935                     N
#
# [263936 rows x 9 columns]

# %%
# Test whether MeSH term names are unique
len(term_df) == len(set(term_df.TermName))
# Out:
# False

# %%
dup_termname = term_df[term_df.duplicated('TermName', keep=False) == True]
dup_termname #https://www.ncbi.nlm.nih.gov/mesh/?term=D000081207 it do have duplicated entry term
# Out:
#       DescriptorUI   ConceptUI PreferredConceptYN      TermUI  \
# 19706   D000081207  M000650100                  N  T000999067
# 19715   D000081207  M000650100                  N  T000958692
# 50398      D002522    M0003848                  Y     T007361
# 50410      D002522    M0003850                  N     T007362
# 71491      D005175    M0008159                  Y     T751631
# 71498      D005175    M0008159                  Y  T000913569
# 80191      D006319    M0009934                  Y  T001102790
# 80201      D006319    M0009934                  Y  T001102791
# 99886      D008872    M0013839                  Y  T001078150
# 99887      D008872    M0013839                  Y  T001078148
#
#                                   TermName ConceptPreferredTermYN  \
# 19706  Inherited Immunodeficiency Syndrome                      N
# 19715  Inherited Immunodeficiency Syndrome                      N
# 50398                 African Green Monkey                      N
# 50410                 African Green Monkey                      N
# 71491                 Factor 12 Deficiency                      N
# 71498                 Factor 12 Deficiency                      N
# 80191               Sensoryneural Deafness                      N
# 80201               Sensoryneural Deafness                      N
# 99886                          Micro Waves                      N
# 99887                          Micro Waves                      N
#
#       IsPermutedTermYN LexicalTag RecordPreferredTermYN
# 19706                N        NON                     N
# 19715                Y        NON                     N
# 50398                N        EPO                     N
# 50410                Y        EPO                     N
# 71491                N        NON                     N
# 71498                Y        NON                     N
# 80191                N        NON                     N
# 80201                Y        NON                     N
# 99886                Y        NON                     N
# 99887                N        NON                     N

# %%
# Parse MeSH xml release
terms = list()

for elem in root:
    term = dict()
    term['mesh_id'] = elem.findtext('DescriptorUI')
    term['mesh_name'] = elem.findtext('DescriptorName/String')
    term['semantic_types'] = list({x.text for x in elem.findall(
        'ConceptList/Concept/SemanticTypeList/SemanticType/SemanticTypeUI')})
    term['tree_numbers'] = [x.text for x in elem.findall('TreeNumberList/TreeNumber')]
    terms.append(term)

# %%
terms
# Out:
# [{'mesh_id': 'D000001',
#   'mesh_name': 'Calcimycin',
#   'semantic_types': [],
#   'tree_numbers': ['D02.355.291.933.125',
#    'D02.540.576.625.125',
#    'D03.633.100.221.173',
#    'D04.345.241.654.125',
#    'D04.345.674.625.125']},
#  {'mesh_id': 'D000002',
#   'mesh_name': 'Temefos',
#   'semantic_types': [],
#   'tree_numbers': ['D02.705.400.625.800',
#    'D02.705.539.345.800',
#    'D02.886.300.692.800']},
#  {'mesh_id': 'D000003',
#   'mesh_name': 'Abattoirs',
#   'semantic_types': [],
#   'tree_numbers': ['J01.576.423.200.700.100', 'J03.540.020']},
#  {'mesh_id': 'D000004',
#   'mesh_name': 'Abbreviations as Topic',
#   'semantic_types': [],
#   'tree_numbers': ['L01.559.598.400.556.131']},
#  {'mesh_id': 'D000005',
#   'mesh_name': 'Abdomen',
#   'semantic_types': [],
#   'tree_numbers': ['A01.923.047']},
#  {'mesh_id': 'D000006',
#   'mesh_name': 'Abdomen, Acute',
#   'semantic_types': [],
#   'tree_numbers': ['C23.888.592.612.054.200', 'C23.888.821.030.249']},
#  {'mesh_id': 'D000007',
#   'mesh_name': 'Abdominal Injuries',
#   'semantic_types': [],
#   'tree_numbers': ['C26.017']},
#  {'mesh_id': 'D000008',
#   'mesh_name': 'Abdominal Neoplasms',
#   'semantic_types': [],
#   'tree_numbers': ['C04.588.033']},
#  {'mesh_id': 'D000009',
#   'mesh_name': 'Abdominal Muscles',
#   'semantic_types': [],
#   'tree_numbers': ['A02.633.567.050']},
#  {'mesh_id': 'D000010',
#   'mesh_name': 'Abducens Nerve',
#   'semantic_types': [],
#   'tree_numbers': ['A08.800.800.120.030']},
#  {'mesh_id': 'D000011',
#   'mesh_name': 'Abelson murine leukemia virus',
#   'semantic_types': [],
#   'tree_numbers': ['B04.613.807.375.525.020', 'B04.820.650.375.525.020']},
#  {'mesh_id': 'D000012',
#   'mesh_name': 'Abetalipoproteinemia',
#   'semantic_types': [],
#   'tree_numbers': ['C16.320.565.398.500.440.500',
#    'C18.452.584.500.875.440.500',
#    'C18.452.584.563.500.440.500',
#    'C18.452.648.398.500.440.500']},
#  {'mesh_id': 'D000013',
#   'mesh_name': 'Congenital Abnormalities',
#   'semantic_types': [],
#   'tree_numbers': ['C16.131']},
#  {'mesh_id': 'D000014',
#   'mesh_name': 'Abnormalities, Drug-Induced',
#   'semantic_types': [],
#   'tree_numbers': ['C16.131.042']},
#  {'mesh_id': 'D000015',
#   'mesh_name': 'Abnormalities, Multiple',
#   'semantic_types': [],
#   'tree_numbers': ['C16.131.077']},
#  {'mesh_id': 'D000016',
#   'mesh_name': 'Abnormalities, Radiation-Induced',
#   'semantic_types': [],
#   'tree_numbers': ['C16.131.080',
#    'C26.733.031',
#    'G01.750.748.500.031',
#    'N06.850.460.350.850.500.031',
#    'N06.850.810.300.360.031']},
#  {'mesh_id': 'D000017',
#   'mesh_name': 'ABO Blood-Group System',
#   'semantic_types': [],
#   'tree_numbers': ['D23.050.301.290.031', 'D23.050.705.230.031']},
#  {'mesh_id': 'D000018',
#   'mesh_name': 'Abomasum',
#   'semantic_types': [],
#   'tree_numbers': ['A13.869.106']},
#  {'mesh_id': 'D000019',
#   'mesh_name': 'Abortifacient Agents',
#   'semantic_types': [],
#   'tree_numbers': ['D27.505.696.875.131', 'D27.505.954.705.131']},
#  {'mesh_id': 'D000020',
#   'mesh_name': 'Abortifacient Agents, Nonsteroidal',
#   'semantic_types': [],
#   'tree_numbers': ['D27.505.696.875.131.100', 'D27.505.954.705.131.100']},
#  {'mesh_id': 'D000021',
#   'mesh_name': 'Abortifacient Agents, Steroidal',
#   'semantic_types': [],
#   'tree_numbers': ['D27.505.696.875.131.200', 'D27.505.954.705.131.200']},
#  {'mesh_id': 'D000022',
#   'mesh_name': 'Abortion, Spontaneous',
#   'semantic_types': [],
#   'tree_numbers': ['C12.050.703.039', 'G08.686.784.769.496.125']},
#  {'mesh_id': 'D000023',
#   'mesh_name': 'Abortion Applicants',
#   'semantic_types': [],
#   'tree_numbers': ['M01.050']},
#  {'mesh_id': 'D000024',
#   'mesh_name': 'Abortion, Criminal',
#   'semantic_types': [],
#   'tree_numbers': ['I01.198.240.089']},
#  {'mesh_id': 'D000025',
#   'mesh_name': 'Abortion, Eugenic',
#   'semantic_types': [],
#   'tree_numbers': ['E04.520.050.050']},
#  {'mesh_id': 'D000026',
#   'mesh_name': 'Abortion, Habitual',
#   'semantic_types': [],
#   'tree_numbers': ['C12.050.703.039.089']},
#  {'mesh_id': 'D000027',
#   'mesh_name': 'Abortion, Incomplete',
#   'semantic_types': [],
#   'tree_numbers': ['C12.050.703.039.093']},
#  {'mesh_id': 'D000028',
#   'mesh_name': 'Abortion, Induced',
#   'semantic_types': [],
#   'tree_numbers': ['E04.520.050']},
#  {'mesh_id': 'D000029',
#   'mesh_name': 'Abortion, Legal',
#   'semantic_types': [],
#   'tree_numbers': ['E04.520.050.055']},
#  {'mesh_id': 'D000030',
#   'mesh_name': 'Abortion, Missed',
#   'semantic_types': [],
#   'tree_numbers': ['C12.050.703.039.173']},
#  {'mesh_id': 'D000031',
#   'mesh_name': 'Abortion, Septic',
#   'semantic_types': [],
#   'tree_numbers': ['C01.674.173',
#    'C12.050.703.039.256',
#    'C12.050.703.700.173']},
#  {'mesh_id': 'D000032',
#   'mesh_name': 'Abortion, Therapeutic',
#   'semantic_types': [],
#   'tree_numbers': ['E04.520.050.060']},
#  {'mesh_id': 'D000033',
#   'mesh_name': 'Abortion, Threatened',
#   'semantic_types': [],
#   'tree_numbers': ['C12.050.703.090']},
#  {'mesh_id': 'D000034',
#   'mesh_name': 'Abortion, Veterinary',
#   'semantic_types': [],
#   'tree_numbers': ['C12.050.703.039.422', 'C22.021']},
#  {'mesh_id': 'D000035',
#   'mesh_name': 'Abreaction',
#   'semantic_types': [],
#   'tree_numbers': ['F04.754.720.107']},
#  {'mesh_id': 'D000036',
#   'mesh_name': 'Abrin',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.450.430.700.750.111',
#    'D12.776.503.499.249',
#    'D12.776.765.678.906.111']},
#  {'mesh_id': 'D000037',
#   'mesh_name': 'Abruptio Placentae',
#   'semantic_types': [],
#   'tree_numbers': ['C12.050.703.420.078', 'C12.050.703.590.132']},
#  {'mesh_id': 'D000038',
#   'mesh_name': 'Abscess',
#   'semantic_types': [],
#   'tree_numbers': ['C01.830.025', 'C23.550.470.756.100']},
#  {'mesh_id': 'D000039',
#   'mesh_name': 'Peritonsillar Abscess',
#   'semantic_types': [],
#   'tree_numbers': ['C01.748.561.750.500',
#    'C01.830.025.675',
#    'C07.550.781.750.500',
#    'C08.730.561.750.500',
#    'C09.775.649.750.500']},
#  {'mesh_id': 'D000040',
#   'mesh_name': 'Abscisic Acid',
#   'semantic_types': [],
#   'tree_numbers': ['D02.241.223.268.034',
#    'D02.455.326.271.665.202.061',
#    'D02.455.426.392.368.367.379.249.024',
#    'D02.455.849.131.061',
#    'D02.455.849.765.521.500']},
#  {'mesh_id': 'D000041',
#   'mesh_name': 'Absenteeism',
#   'semantic_types': [],
#   'tree_numbers': ['F02.784.692.107']},
#  {'mesh_id': 'D000042',
#   'mesh_name': 'Absorption',
#   'semantic_types': [],
#   'tree_numbers': ['G01.015',
#    'G02.010',
#    'G03.015',
#    'G03.787.024',
#    'G07.690.725.015']},
#  {'mesh_id': 'D000043',
#   'mesh_name': 'Abstracting and Indexing',
#   'semantic_types': [],
#   'tree_numbers': ['L01.462.750.245.100']},
#  {'mesh_id': 'D000044',
#   'mesh_name': 'Dental Abutments',
#   'semantic_types': [],
#   'tree_numbers': ['E06.780.346.500', 'E07.695.190.175']},
#  {'mesh_id': 'D000045',
#   'mesh_name': 'Acacia',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.401.025']},
#  {'mesh_id': 'D000046',
#   'mesh_name': 'Academic Medical Centers',
#   'semantic_types': [],
#   'tree_numbers': ['N02.278.020']},
#  {'mesh_id': 'D000047',
#   'mesh_name': 'Academies and Institutes',
#   'semantic_types': [],
#   'tree_numbers': ['N03.540.052']},
#  {'mesh_id': 'D000048',
#   'mesh_name': 'Acanthamoeba',
#   'semantic_types': [],
#   'tree_numbers': ['B01.046.500.100.075.080']},
#  {'mesh_id': 'D000049',
#   'mesh_name': 'Acanthocephala',
#   'semantic_types': [],
#   'tree_numbers': ['B01.050.500.500.132']},
#  {'mesh_id': 'D000050',
#   'mesh_name': 'Acanthocytes',
#   'semantic_types': [],
#   'tree_numbers': ['A11.118.290.330.100',
#    'A11.443.240.330.100',
#    'A15.145.229.334.330.100']},
#  {'mesh_id': 'D000051',
#   'mesh_name': 'Acantholysis',
#   'semantic_types': [],
#   'tree_numbers': ['C17.800.865.070', 'C23.550.035']},
#  {'mesh_id': 'D000052',
#   'mesh_name': 'Acanthosis Nigricans',
#   'semantic_types': [],
#   'tree_numbers': ['C17.800.621.430.530.100']},
#  {'mesh_id': 'D000053',
#   'mesh_name': 'Acari',
#   'semantic_types': [],
#   'tree_numbers': ['B01.050.500.131.166.132']},
#  {'mesh_id': 'D000054',
#   'mesh_name': 'Acceleration',
#   'semantic_types': [],
#   'tree_numbers': ['G01.482.107']},
#  {'mesh_id': 'D000055',
#   'mesh_name': 'Accessory Nerve',
#   'semantic_types': [],
#   'tree_numbers': ['A08.800.800.120.060']},
#  {'mesh_id': 'D000056',
#   'mesh_name': 'Accident Prevention',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.135.060']},
#  {'mesh_id': 'D000057',
#   'mesh_name': 'Accident Proneness',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.015']},
#  {'mesh_id': 'D000058',
#   'mesh_name': 'Accidental Falls',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.135.122']},
#  {'mesh_id': 'D000059',
#   'mesh_name': 'Accidents',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.135']},
#  {'mesh_id': 'D000060',
#   'mesh_name': 'Accidents, Aviation',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.135.185']},
#  {'mesh_id': 'D000061',
#   'mesh_name': 'Accidents, Home',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.135.217']},
#  {'mesh_id': 'D000062',
#   'mesh_name': 'Accidents, Occupational',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.135.240']},
#  {'mesh_id': 'D000063',
#   'mesh_name': 'Accidents, Traffic',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.135.392']},
#  {'mesh_id': 'D000064',
#   'mesh_name': 'Acclimatization',
#   'semantic_types': [],
#   'tree_numbers': ['G07.025.133', 'G16.012.500.133']},
#  {'mesh_id': 'D000065',
#   'mesh_name': 'Accommodation, Ocular',
#   'semantic_types': [],
#   'tree_numbers': ['G14.010']},
#  {'mesh_id': 'D000066',
#   'mesh_name': 'Accounting',
#   'semantic_types': [],
#   'tree_numbers': ['N03.219.463.030']},
#  {'mesh_id': 'D000066388',
#   'mesh_name': 'Oil and Gas Industry',
#   'semantic_types': [],
#   'tree_numbers': ['J01.576.655.875.750']},
#  {'mesh_id': 'D000066428',
#   'mesh_name': 'Coal Industry',
#   'semantic_types': [],
#   'tree_numbers': ['J01.576.655.875.200']},
#  {'mesh_id': 'D000066448',
#   'mesh_name': 'Driving Under the Influence',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.250.250',
#    'F01.145.263.500',
#    'I01.880.735.223.250',
#    'I03.125.649']},
#  {'mesh_id': 'D000066449',
#   'mesh_name': 'Human Embryonic Stem Cells',
#   'semantic_types': [],
#   'tree_numbers': ['A11.872.700.250.750']},
#  {'mesh_id': 'D000066450',
#   'mesh_name': 'Mouse Embryonic Stem Cells',
#   'semantic_types': [],
#   'tree_numbers': ['A11.872.700.250.875']},
#  {'mesh_id': 'D000066473',
#   'mesh_name': 'Embryonic Germ Cells',
#   'semantic_types': [],
#   'tree_numbers': ['A11.497.124', 'A11.872.700.250.625']},
#  {'mesh_id': 'D000066477',
#   'mesh_name': 'Work Performance',
#   'semantic_types': [],
#   'tree_numbers': ['I03.946.675']},
#  {'mesh_id': 'D000066479',
#   'mesh_name': 'Criminal Behavior',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.250']},
#  {'mesh_id': 'D000066491',
#   'mesh_name': 'Clinical Decision-Making',
#   'semantic_types': [],
#   'tree_numbers': ['E01.055']},
#  {'mesh_id': 'D000066492',
#   'mesh_name': 'Cognitive Aging',
#   'semantic_types': [],
#   'tree_numbers': ['G07.345.124.260']},
#  {'mesh_id': 'D000066494',
#   'mesh_name': 'Cognitive Neuroscience',
#   'semantic_types': [],
#   'tree_numbers': ['F04.096.628.255.500', 'H01.158.610.030']},
#  {'mesh_id': 'D000066498',
#   'mesh_name': 'Emotional Adjustment',
#   'semantic_types': [],
#   'tree_numbers': ['F01.058.144', 'F01.752.543.500.250']},
#  {'mesh_id': 'D000066499',
#   'mesh_name': 'Facial Recognition',
#   'semantic_types': [],
#   'tree_numbers': ['F02.463.593.524.250.500',
#    'F02.463.593.524.500.500',
#    'F02.463.593.932.622.500']},
#  {'mesh_id': 'D000066502',
#   'mesh_name': 'Grandparents',
#   'semantic_types': [],
#   'tree_numbers': ['F01.829.263.403', 'I01.880.853.150.452', 'M01.264']},
#  {'mesh_id': 'D000066505',
#   'mesh_name': 'Help-Seeking Behavior',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.813.217']},
#  {'mesh_id': 'D000066506',
#   'mesh_name': 'Heuristics',
#   'semantic_types': [],
#   'tree_numbers': ['F02.463.425.725.500', 'F02.463.785.810.500']},
#  {'mesh_id': 'D000066511',
#   'mesh_name': 'Intimate Partner Violence',
#   'semantic_types': [],
#   'tree_numbers': ['I01.198.240.856.575', 'I01.880.735.900.688']},
#  {'mesh_id': 'D000066530',
#   'mesh_name': 'Neurological Rehabilitation',
#   'semantic_types': [],
#   'tree_numbers': ['E02.760.169.063.500.477',
#    'E02.831.477',
#    'H02.403.680.600.750',
#    'N02.421.784.511']},
#  {'mesh_id': 'D000066550',
#   'mesh_name': 'Physical Abuse',
#   'semantic_types': [],
#   'tree_numbers': ['I01.198.240.856.688', 'I01.880.735.900.744']},
#  {'mesh_id': 'D000066553',
#   'mesh_name': 'Problem Behavior',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.126.972', 'F01.145.179.750']},
#  {'mesh_id': 'D000066608',
#   'mesh_name': 'Underage Drinking',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.022.750',
#    'F01.145.317.269.875',
#    'I01.880.735.878']},
#  {'mesh_id': 'D000066630',
#   'mesh_name': 'Ectopic Gene Expression',
#   'semantic_types': [],
#   'tree_numbers': ['G05.308.202']},
#  {'mesh_id': 'D000066670',
#   'mesh_name': 'Cell Plasticity',
#   'semantic_types': [],
#   'tree_numbers': ['G04.356.250']},
#  {'mesh_id': 'D000066673',
#   'mesh_name': 'Cell Self Renewal',
#   'semantic_types': [],
#   'tree_numbers': ['G04.144.220.235',
#    'G04.161.750.500.375',
#    'G05.113.415',
#    'G07.345.249.410.750.500.625']},
#  {'mesh_id': 'D000066768',
#   'mesh_name': 'Rehabilitation Research',
#   'semantic_types': [],
#   'tree_numbers': ['H01.770.644.145.472']},
#  {'mesh_id': 'D000066792',
#   'mesh_name': 'Orthodontists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.330.330.655', 'N02.360.330.330.655']},
#  {'mesh_id': 'D000066794',
#   'mesh_name': 'Oral and Maxillofacial Surgeons',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.330.330.483',
#    'M01.526.485.810.910.813',
#    'N02.360.330.330.483',
#    'N02.360.810.910.813']},
#  {'mesh_id': 'D000066829',
#   'mesh_name': 'Neuroprotection',
#   'semantic_types': [],
#   'tree_numbers': ['G11.561.645']},
#  {'mesh_id': 'D000066888',
#   'mesh_name': 'Diet, Food, and Nutrition',
#   'semantic_types': [],
#   'tree_numbers': ['G07.203']},
#  {'mesh_id': 'D000066889',
#   'mesh_name': 'Triticale',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.822.906']},
#  {'mesh_id': 'D000066891',
#   'mesh_name': 'Critical Care Outcomes',
#   'semantic_types': [],
#   'tree_numbers': ['N04.761.559.590.399.250', 'N05.715.360.575.575.399.250']},
#  {'mesh_id': 'D000066908',
#   'mesh_name': 'Simulation Training',
#   'semantic_types': [],
#   'tree_numbers': ['I02.903.847']},
#  {'mesh_id': 'D000066928',
#   'mesh_name': 'Millets',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.822.587']},
#  {'mesh_id': 'D000066949',
#   'mesh_name': 'Biobehavioral Sciences',
#   'semantic_types': [],
#   'tree_numbers': ['H01.770.644.108.687']},
#  {'mesh_id': 'D000066970',
#   'mesh_name': 'Protein Corona',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.791']},
#  {'mesh_id': 'D000066988',
#   'mesh_name': 'Vegetarians',
#   'semantic_types': [],
#   'tree_numbers': ['M01.928']},
#  {'mesh_id': 'D000066989',
#   'mesh_name': 'Vegans',
#   'semantic_types': [],
#   'tree_numbers': ['M01.928.500']},
#  {'mesh_id': 'D000067',
#   'mesh_name': 'Accounts Payable and Receivable',
#   'semantic_types': [],
#   'tree_numbers': ['N03.219.463.030.080']},
#  {'mesh_id': 'D000067009',
#   'mesh_name': 'Youth Sports',
#   'semantic_types': [],
#   'tree_numbers': ['I03.450.642.845.987']},
#  {'mesh_id': 'D000067010',
#   'mesh_name': 'Literacy',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.209.429', 'N01.824.196.500']},
#  {'mesh_id': 'D000067011',
#   'mesh_name': 'Severe Acute Malnutrition',
#   'semantic_types': [],
#   'tree_numbers': ['C18.654.521.719']},
#  {'mesh_id': 'D000067012',
#   'mesh_name': 'Banking, Personal',
#   'semantic_types': [],
#   'tree_numbers': ['N03.219.463.030.100']},
#  {'mesh_id': 'D000067013',
#   'mesh_name': 'Evidence-Based Facility Design',
#   'semantic_types': [],
#   'tree_numbers': ['N02.278.200.252']},
#  {'mesh_id': 'D000067029',
#   'mesh_name': 'Physical Appearance, Body',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.600.115.450', 'G07.100.175']},
#  {'mesh_id': 'D000067030',
#   'mesh_name': 'Fruit and Vegetable Juices',
#   'semantic_types': [],
#   'tree_numbers': ['G07.203.100.606', 'J02.200.606']},
#  {'mesh_id': 'D000067048',
#   'mesh_name': 'Ghee',
#   'semantic_types': [],
#   'tree_numbers': ['D10.212.302.199.500',
#    'G07.203.300.350.100.500',
#    'G07.203.300.375.200.500',
#    'J02.500.350.100.500',
#    'J02.500.375.200.500']},
#  {'mesh_id': 'D000067071',
#   'mesh_name': 'Hydraulic Fracking',
#   'semantic_types': [],
#   'tree_numbers': ['J01.576.655.875.750.500']},
#  {'mesh_id': 'D000067073',
#   'mesh_name': 'Psychological Trauma',
#   'semantic_types': [],
#   'tree_numbers': ['F03.950.750.375']},
#  {'mesh_id': 'D000067074',
#   'mesh_name': 'Peer Influence',
#   'semantic_types': [],
#   'tree_numbers': ['F01.829.316.223.750', 'F01.829.316.483.750']},
#  {'mesh_id': 'D000067075',
#   'mesh_name': 'Vegetable Products',
#   'semantic_types': [],
#   'tree_numbers': ['G07.203.300.850.450', 'J02.500.850.800']},
#  {'mesh_id': 'D000067088',
#   'mesh_name': 'Direct-to-Consumer Advertising',
#   'semantic_types': [],
#   'tree_numbers': ['J01.219.687.274.500']},
#  {'mesh_id': 'D000067108',
#   'mesh_name': 'Direct-To-Consumer Screening and Testing',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.398', 'N02.421.726.233.166']},
#  {'mesh_id': 'D000067128',
#   'mesh_name': 'Extracellular Vesicles',
#   'semantic_types': [],
#   'tree_numbers': ['A11.284.295.588']},
#  {'mesh_id': 'D000067148',
#   'mesh_name': 'Fungal Viruses',
#   'semantic_types': [],
#   'tree_numbers': ['B04.352']},
#  {'mesh_id': 'D000067170',
#   'mesh_name': 'Telocytes',
#   'semantic_types': [],
#   'tree_numbers': ['A11.329.830.750']},
#  {'mesh_id': 'D000067190',
#   'mesh_name': 'Exoskeleton Device',
#   'semantic_types': [],
#   'tree_numbers': ['E07.341']},
#  {'mesh_id': 'D000067208',
#   'mesh_name': 'Shellfish Hypersensitivity',
#   'semantic_types': [],
#   'tree_numbers': ['C20.543.480.370.763']},
#  {'mesh_id': 'D000067248',
#   'mesh_name': 'Failure to Rescue, Health Care',
#   'semantic_types': [],
#   'tree_numbers': ['E01.789.800.760.500',
#    'H01.770.644.145.431.500',
#    'N04.761.559.590.800.760.500',
#    'N05.715.360.575.575.800.760.500']},
#  {'mesh_id': 'D000067250',
#   'mesh_name': 'Psychiatric Rehabilitation',
#   'semantic_types': [],
#   'tree_numbers': ['H02.403.680.600.875', 'N02.421.784.578']},
#  {'mesh_id': 'D000067251',
#   'mesh_name': 'Symptom Flare Up',
#   'semantic_types': [],
#   'tree_numbers': ['C23.550.291.937.500']},
#  {'mesh_id': 'D000067268',
#   'mesh_name': 'Isolated Heart Preparation',
#   'semantic_types': [],
#   'tree_numbers': ['E05.519', 'E05.598.750']},
#  {'mesh_id': 'D000067269',
#   'mesh_name': 'Diet, Vegan',
#   'semantic_types': [],
#   'tree_numbers': ['E02.642.249.278.500.750', 'G07.203.650.240.278.500.750']},
#  {'mesh_id': 'D000067289',
#   'mesh_name': 'Behavior Observation Techniques',
#   'semantic_types': [],
#   'tree_numbers': ['E05.796.112', 'F04.669.112']},
#  {'mesh_id': 'D000067290',
#   'mesh_name': 'Behavior Rating Scale',
#   'semantic_types': [],
#   'tree_numbers': ['F04.711.271']},
#  {'mesh_id': 'D000067292',
#   'mesh_name': 'Alcohol Drinking in College',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.317.269.625']},
#  {'mesh_id': 'D000067329',
#   'mesh_name': 'Obesity, Metabolically Benign',
#   'semantic_types': [],
#   'tree_numbers': ['C18.654.726.750.500.650', 'C23.888.144.699.500.250']},
#  {'mesh_id': 'D000067348',
#   'mesh_name': 'Whole Grains',
#   'semantic_types': [],
#   'tree_numbers': ['G07.203.300.300.550.500',
#    'G07.203.300.775.500.500',
#    'J02.500.300.550.500',
#    'J02.500.775.500.500']},
#  {'mesh_id': 'D000067368',
#   'mesh_name': 'Transanal Endoscopic Surgery',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.388.250.630.500',
#    'E04.210.240.250.680.500',
#    'E04.502.250.250.250.680.500',
#    'E04.502.250.630.500']},
#  {'mesh_id': 'D000067369',
#   'mesh_name': 'Transanal Endoscopic Microsurgery',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.388.250.630.500.500',
#    'E04.210.240.250.680.500.500',
#    'E04.494.787',
#    'E04.502.250.250.250.680.500.500',
#    'E04.502.250.630.500.500']},
#  {'mesh_id': 'D000067390',
#   'mesh_name': 'Cold Injury',
#   'semantic_types': [],
#   'tree_numbers': ['C26.212']},
#  {'mesh_id': 'D000067393',
#   'mesh_name': 'Personal Protective Equipment',
#   'semantic_types': [],
#   'tree_numbers': ['E07.700.560', 'J01.637.708.560']},
#  {'mesh_id': 'D000067397',
#   'mesh_name': 'Nerve Agents',
#   'semantic_types': [],
#   'tree_numbers': ['D27.720.599', 'D27.720.777.300.500']},
#  {'mesh_id': 'D000067398',
#   'mesh_name': 'War-Related Injuries',
#   'semantic_types': [],
#   'tree_numbers': ['C26.946', 'I01.880.735.950.500.951.500']},
#  {'mesh_id': 'D000067399',
#   'mesh_name': 'Abnormal Involuntary Movement Scale',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.600.550.162']},
#  {'mesh_id': 'D000067401',
#   'mesh_name': 'Blood Alcohol Content',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.375.135']},
#  {'mesh_id': 'D000067404',
#   'mesh_name': 'Social Communication Disorder',
#   'semantic_types': [],
#   'tree_numbers': ['F03.625.374.250']},
#  {'mesh_id': 'D000067408',
#   'mesh_name': 'Legal Services',
#   'semantic_types': [],
#   'tree_numbers': ['I01.880.604.583.482']},
#  {'mesh_id': 'D000067448',
#   'mesh_name': 'Defamation',
#   'semantic_types': [],
#   'tree_numbers': ['I01.198.240.240', 'I01.880.735.191.051']},
#  {'mesh_id': 'D000067449',
#   'mesh_name': 'Anger Management Therapy',
#   'semantic_types': [],
#   'tree_numbers': ['F04.754.137.087']},
#  {'mesh_id': 'D000067450',
#   'mesh_name': 'Psychology, Sports',
#   'semantic_types': [],
#   'tree_numbers': ['F04.096.628.914']},
#  {'mesh_id': 'D000067453',
#   'mesh_name': 'War Exposure',
#   'semantic_types': [],
#   'tree_numbers': ['I01.880.735.950.500.951', 'N06.850.460.350.600.903']},
#  {'mesh_id': 'D000067454',
#   'mesh_name': 'Childhood-Onset Fluency Disorder',
#   'semantic_types': [],
#   'tree_numbers': ['F03.625.374.125']},
#  {'mesh_id': 'D000067455',
#   'mesh_name': 'No-Show Patients',
#   'semantic_types': [],
#   'tree_numbers': ['F01.100.150.750.500.600.750',
#    'F01.145.488.887.500.600.750',
#    'M01.643.550',
#    'N04.452.758.635.500',
#    'N05.300.150.800.500.600.750']},
#  {'mesh_id': 'D000067470',
#   'mesh_name': 'Cellular Reprogramming Techniques',
#   'semantic_types': [],
#   'tree_numbers': ['E05.200.500.380', 'E05.242.378', 'E05.393.085']},
#  {'mesh_id': 'D000067489',
#   'mesh_name': 'Metacognition',
#   'semantic_types': [],
#   'tree_numbers': ['F02.463.188.756']},
#  {'mesh_id': 'D000067490',
#   'mesh_name': 'Prescription Drug Overuse',
#   'semantic_types': [],
#   'tree_numbers': ['C25.775.342.500.750', 'F03.900.384.500.750']},
#  {'mesh_id': 'D000067491',
#   'mesh_name': 'Near Miss, Healthcare',
#   'semantic_types': [],
#   'tree_numbers': ['E02.319.529.750',
#    'N02.421.450.500.750',
#    'N02.421.450.550',
#    'N04.761.700.594',
#    'N05.700.513']},
#  {'mesh_id': 'D000067492',
#   'mesh_name': 'RNAi Therapeutics',
#   'semantic_types': [],
#   'tree_numbers': ['E02.095.301.250']},
#  {'mesh_id': 'D000067493',
#   'mesh_name': 'Dynamic Light Scattering',
#   'semantic_types': [],
#   'tree_numbers': ['E05.196.822.325']},
#  {'mesh_id': 'D000067494',
#   'mesh_name': 'Time Out, Healthcare',
#   'semantic_types': [],
#   'tree_numbers': ['N04.761.700.635', 'N05.700.739']},
#  {'mesh_id': 'D000067495',
#   'mesh_name': 'Healthcare Failure Mode and Effect Analysis',
#   'semantic_types': [],
#   'tree_numbers': ['E05.318.740.600.800.715.500',
#    'N04.452.871.715.400',
#    'N05.715.360.750.625.700.690.400',
#    'N06.850.505.715.500',
#    'N06.850.520.830.600.800.715.500']},
#  {'mesh_id': 'D000067496',
#   'mesh_name': 'Spirit Possession',
#   'semantic_types': [],
#   'tree_numbers': ['K01.844.619.500']},
#  {'mesh_id': 'D000067498',
#   'mesh_name': 'Crew Resource Management, Healthcare',
#   'semantic_types': [],
#   'tree_numbers': ['N04.590.254']},
#  {'mesh_id': 'D000067508',
#   'mesh_name': 'Computer Heuristics',
#   'semantic_types': [],
#   'tree_numbers': ['L01.224.050.375.095']},
#  {'mesh_id': 'D000067528',
#   'mesh_name': 'Ataxins',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.631.069', 'D12.776.660.075']},
#  {'mesh_id': 'D000067531',
#   'mesh_name': 'Alarmins',
#   'semantic_types': [],
#   'tree_numbers': ['D23.469.025']},
#  {'mesh_id': 'D000067548',
#   'mesh_name': 'Dermal Fillers',
#   'semantic_types': [],
#   'tree_numbers': ['D27.720.102.461']},
#  {'mesh_id': 'D000067549',
#   'mesh_name': 'Action Spectrum',
#   'semantic_types': [],
#   'tree_numbers': ['E05.196.867.826.150']},
#  {'mesh_id': 'D000067551',
#   'mesh_name': 'Diplomacy',
#   'semantic_types': [],
#   'tree_numbers': ['F01.829.316.171',
#    'F02.463.785.373.520.500',
#    'I01.738.305']},
#  {'mesh_id': 'D000067552',
#   'mesh_name': 'Mutation Accumulation',
#   'semantic_types': [],
#   'tree_numbers': ['G05.365.590.594']},
#  {'mesh_id': 'D000067556',
#   'mesh_name': 'Internal Ribosome Entry Sites',
#   'semantic_types': [],
#   'tree_numbers': ['D13.444.735.790.878.942.250',
#    'G02.111.570.080.689.687.093',
#    'G05.360.080.689.687.093']},
#  {'mesh_id': 'D000067558',
#   'mesh_name': 'Biological Mimicry',
#   'semantic_types': [],
#   'tree_numbers': ['G16.012.750']},
#  {'mesh_id': 'D000067559',
#   'mesh_name': 'Specific Learning Disorder',
#   'semantic_types': [],
#   'tree_numbers': ['C10.597.606.150.550.700',
#    'C23.888.592.604.150.550.700',
#    'F03.625.374.188.700',
#    'F03.625.562.700']},
#  {'mesh_id': 'D000067561',
#   'mesh_name': 'Potentially Inappropriate Medication List',
#   'semantic_types': [],
#   'tree_numbers': ['N04.761.700.615', 'N05.700.594']},
#  {'mesh_id': 'D000067562',
#   'mesh_name': 'Late Onset Disorders',
#   'semantic_types': [],
#   'tree_numbers': ['C23.550.291.883']},
#  {'mesh_id': 'D000067563',
#   'mesh_name': 'Phakopsora pachyrhizi',
#   'semantic_types': [],
#   'tree_numbers': ['B01.300.179.113']},
#  {'mesh_id': 'D000067565',
#   'mesh_name': 'Farmers',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.390']},
#  {'mesh_id': 'D000067568',
#   'mesh_name': 'Culturally Appropriate Technology',
#   'semantic_types': [],
#   'tree_numbers': ['J01.897.052']},
#  {'mesh_id': 'D000067570',
#   'mesh_name': 'Social Learning',
#   'semantic_types': [],
#   'tree_numbers': ['F02.784.629.529.663']},
#  {'mesh_id': 'D000067571',
#   'mesh_name': 'Financial Statements',
#   'semantic_types': [],
#   'tree_numbers': ['N03.219.463.030.140']},
#  {'mesh_id': 'D000067572',
#   'mesh_name': 'Miners',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.693']},
#  {'mesh_id': 'D000067573',
#   'mesh_name': 'Chronopharmacokinetics',
#   'semantic_types': [],
#   'tree_numbers': ['G07.690.725.249']},
#  {'mesh_id': 'D000067575',
#   'mesh_name': 'Administrative Claims, Healthcare',
#   'semantic_types': [],
#   'tree_numbers': ['N04.452.859.564.137']},
#  {'mesh_id': 'D000067576',
#   'mesh_name': 'Child Health',
#   'semantic_types': [],
#   'tree_numbers': ['N01.400.225']},
#  {'mesh_id': 'D000067596',
#   'mesh_name': 'Interleukin-33',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.276.374.465.850',
#    'D12.776.467.374.465.850',
#    'D23.529.374.465.850']},
#  {'mesh_id': 'D000067616',
#   'mesh_name': 'S100A12 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.125.750.875']},
#  {'mesh_id': 'D000067617',
#   'mesh_name': 'Telopodes',
#   'semantic_types': [],
#   'tree_numbers': ['A11.284.180.900', 'A11.329.830.750.500']},
#  {'mesh_id': 'D000067636',
#   'mesh_name': 'Drosophila simulans',
#   'semantic_types': [],
#   'tree_numbers': ['B01.050.500.131.617.720.500.500.750.310.250.750']},
#  {'mesh_id': 'D000067656',
#   'mesh_name': 'Optimism',
#   'semantic_types': [],
#   'tree_numbers': ['F01.100.787']},
#  {'mesh_id': 'D000067657',
#   'mesh_name': 'Pessimism',
#   'semantic_types': [],
#   'tree_numbers': ['F01.100.893']},
#  {'mesh_id': 'D000067696',
#   'mesh_name': 'Ataxin-1',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.631.069.500', 'D12.776.660.075.500']},
#  {'mesh_id': 'D000067697',
#   'mesh_name': 'Adolescent Health',
#   'semantic_types': [],
#   'tree_numbers': ['N01.400.075']},
#  {'mesh_id': 'D000067698',
#   'mesh_name': 'Ataxin-2',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.452.125',
#    'D12.776.631.069.750',
#    'D12.776.660.075.750',
#    'D12.776.664.962.452.125']},
#  {'mesh_id': 'D000067699',
#   'mesh_name': 'Ataxin-3',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.037.250',
#    'D12.776.631.069.875',
#    'D12.776.660.075.875']},
#  {'mesh_id': 'D000067716',
#   'mesh_name': 'Point-of-Care Testing',
#   'semantic_types': [],
#   'tree_numbers': ['N04.590.874.500']},
#  {'mesh_id': 'D000067719',
#   'mesh_name': 'Ataxin-7',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.631.069.901', 'D12.776.660.075.900']},
#  {'mesh_id': 'D000067736',
#   'mesh_name': 'Ataxin-10',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.631.069.950']},
#  {'mesh_id': 'D000067756',
#   'mesh_name': 'Glucagon-Like Peptide Receptors',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.695.021', 'D12.776.543.750.750.360.100']},
#  {'mesh_id': 'D000067757',
#   'mesh_name': 'Glucagon-Like Peptide-1 Receptor',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.695.021.500',
#    'D12.776.543.750.750.360.100.500']},
#  {'mesh_id': 'D000067758',
#   'mesh_name': 'Glucagon-Like Peptide-2 Receptor',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.695.021.600',
#    'D12.776.543.750.750.360.100.600']},
#  {'mesh_id': 'D000067759',
#   'mesh_name': 'Receptor for Advanced Glycation End Products',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.615', 'D23.469.850']},
#  {'mesh_id': 'D000067776',
#   'mesh_name': 'RNA Recognition Motif Proteins',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.813', 'D12.776.664.962.813']},
#  {'mesh_id': 'D000067777',
#   'mesh_name': 'ELAV-Like Protein 2',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.813.500.500',
#    'D12.776.631.520.500',
#    'D12.776.664.962.813.500.500']},
#  {'mesh_id': 'D000067778',
#   'mesh_name': 'ELAV-Like Protein 3',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.813.500.750',
#    'D12.776.631.520.750',
#    'D12.776.664.962.813.500.750']},
#  {'mesh_id': 'D000067779',
#   'mesh_name': 'ELAV-Like Protein 4',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.813.500.875',
#    'D12.776.631.520.875',
#    'D12.776.664.962.813.500.875']},
#  {'mesh_id': 'D000067780',
#   'mesh_name': 'ELAV-Like Protein 1',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.813.500.250',
#    'D12.776.664.962.813.500.250']},
#  {'mesh_id': 'D000067796',
#   'mesh_name': 'Whey',
#   'semantic_types': [],
#   'tree_numbers': ['A12.790.760',
#    'G07.203.100.700.750',
#    'G07.203.300.350.525.760',
#    'J02.200.700.750',
#    'J02.500.350.525.760']},
#  {'mesh_id': 'D000067816',
#   'mesh_name': 'Whey Proteins',
#   'semantic_types': [],
#   'tree_numbers': ['A12.790.520.500',
#    'A12.790.760.500',
#    'D12.776.256.159.750.816',
#    'G07.203.300.350.525.760.500',
#    'G07.203.300.428.159.812.500',
#    'J02.500.350.525.520.500',
#    'J02.500.350.525.760.500',
#    'J02.500.428.159.750.500']},
#  {'mesh_id': 'D000067836',
#   'mesh_name': 'Hoarding Disorder',
#   'semantic_types': [],
#   'tree_numbers': ['F03.080.600.250']},
#  {'mesh_id': 'D000067856',
#   'mesh_name': 'Poly(ADP-ribose) Polymerase Inhibitors',
#   'semantic_types': [],
#   'tree_numbers': ['D27.505.519.389.739', 'D27.505.954.248.692']},
#  {'mesh_id': 'D000067877',
#   'mesh_name': 'Autism Spectrum Disorder',
#   'semantic_types': [],
#   'tree_numbers': ['F03.625.164.113']},
#  {'mesh_id': 'D000067878',
#   'mesh_name': 'CELF Proteins',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.813.250', 'D12.776.664.962.813.250']},
#  {'mesh_id': 'D000067879',
#   'mesh_name': 'CELF1 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.813.250.500',
#    'D12.776.664.962.813.250.500']},
#  {'mesh_id': 'D000067896',
#   'mesh_name': 'Industrial Development',
#   'semantic_types': [],
#   'tree_numbers': ['I01.261.262.500', 'J01.576.519']},
#  {'mesh_id': 'D000067917',
#   'mesh_name': 'Cloud Computing',
#   'semantic_types': [],
#   'tree_numbers': ['L01.224.097']},
#  {'mesh_id': 'D000067936',
#   'mesh_name': 'Natural Resources',
#   'semantic_types': [],
#   'tree_numbers': ['G16.500.275.553', 'J01.728', 'N06.230.350']},
#  {'mesh_id': 'D000067940',
#   'mesh_name': 'Glycemic Load',
#   'semantic_types': [],
#   'tree_numbers': ['G07.203.650.660.750',
#    'J01.576.423.850.730.750.750',
#    'N06.850.601.750.750']},
#  {'mesh_id': 'D000067956',
#   'mesh_name': 'Adenylyl Cyclase Inhibitors',
#   'semantic_types': [],
#   'tree_numbers': ['D27.505.519.389.108']},
#  {'mesh_id': 'D000067996',
#   'mesh_name': 'RAW 264.7 Cells',
#   'semantic_types': [],
#   'tree_numbers': ['A11.251.210.172.875', 'A11.733.397.815']},
#  {'mesh_id': 'D000068',
#   'mesh_name': 'Accreditation',
#   'semantic_types': [],
#   'tree_numbers': ['N03.706.110.070', 'N05.700.200.100']},
#  {'mesh_id': 'D000068016',
#   'mesh_name': 'Clostridiales',
#   'semantic_types': [],
#   'tree_numbers': ['B03.353.625']},
#  {'mesh_id': 'D000068036',
#   'mesh_name': 'Graphic Novel',
#   'semantic_types': [],
#   'tree_numbers': ['V02.700.225.500']},
#  {'mesh_id': 'D000068037',
#   'mesh_name': 'South Sudan',
#   'semantic_types': [],
#   'tree_numbers': ['Z01.058.290.120.745']},
#  {'mesh_id': 'D000068079',
#   'mesh_name': 'Motor Disorders',
#   'semantic_types': [],
#   'tree_numbers': ['F03.608']},
#  {'mesh_id': 'D000068097',
#   'mesh_name': 'Maternal Health',
#   'semantic_types': [],
#   'tree_numbers': ['N01.400.900.500']},
#  {'mesh_id': 'D000068098',
#   'mesh_name': 'Seed Bank',
#   'semantic_types': [],
#   'tree_numbers': ['N02.278.065.650']},
#  {'mesh_id': 'D000068099',
#   'mesh_name': 'Trauma and Stressor Related Disorders',
#   'semantic_types': [],
#   'tree_numbers': ['F03.950']},
#  {'mesh_id': 'D000068101',
#   'mesh_name': 'Maternal-Child Health Services',
#   'semantic_types': [],
#   'tree_numbers': ['N02.421.143.130.660', 'N02.421.143.620.275']},
#  {'mesh_id': 'D000068103',
#   'mesh_name': 'Serine-Arginine Splicing Factors',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.829.500', 'D12.776.664.962.829.500']},
#  {'mesh_id': 'D000068104',
#   'mesh_name': 'Infant Health',
#   'semantic_types': [],
#   'tree_numbers': ['N01.400.388']},
#  {'mesh_id': 'D000068105',
#   'mesh_name': 'Bipolar and Related Disorders',
#   'semantic_types': [],
#   'tree_numbers': ['F03.600.150']},
#  {'mesh_id': 'D000068116',
#   'mesh_name': 'Gender Dysphoria',
#   'semantic_types': [],
#   'tree_numbers': ['F03.835.550']},
#  {'mesh_id': 'D000068156',
#   'mesh_name': 'Formative Feedback',
#   'semantic_types': [],
#   'tree_numbers': ['F02.784.629.529.223']},
#  {'mesh_id': 'D000068180',
#   'mesh_name': 'Aripiprazole',
#   'semantic_types': [],
#   'tree_numbers': ['D03.383.606.170', 'D03.633.100.810.835.122']},
#  {'mesh_id': 'D000068181',
#   'mesh_name': 'Prunus dulcis',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.859.937.500.625.500']},
#  {'mesh_id': 'D000068196',
#   'mesh_name': 'Albumin-Bound Paclitaxel',
#   'semantic_types': [],
#   'tree_numbers': ['D02.455.426.392.368.242.888.777.500',
#    'D02.455.849.291.850.777.500',
#    'D12.776.034.073']},
#  {'mesh_id': 'D000068216',
#   'mesh_name': 'Child Protective Services',
#   'semantic_types': [],
#   'tree_numbers': ['I01.409.418.500', 'N03.540.400.500']},
#  {'mesh_id': 'D000068217',
#   'mesh_name': 'Social Workers',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.919']},
#  {'mesh_id': 'D000068218',
#   'mesh_name': 'Prunus africana',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.859.937.500.625.250']},
#  {'mesh_id': 'D000068219',
#   'mesh_name': 'Prunus armeniaca',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.859.937.500.625.375']},
#  {'mesh_id': 'D000068220',
#   'mesh_name': 'Prunus avium',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.859.937.500.625.400']},
#  {'mesh_id': 'D000068236',
#   'mesh_name': 'Refugium',
#   'semantic_types': [],
#   'tree_numbers': ['G16.500.275.683', 'G16.500.819']},
#  {'mesh_id': 'D000068237',
#   'mesh_name': 'Distance Counseling',
#   'semantic_types': [],
#   'tree_numbers': ['F02.784.176.350',
#    'F04.408.413.437',
#    'H02.403.840.150',
#    'L01.462.500.847.652.138',
#    'N02.421.143.303.175',
#    'N02.421.461.363.437',
#    'N04.452.758.849.550.500',
#    'N04.590.374.800.138']},
#  {'mesh_id': 'D000068238',
#   'mesh_name': 'Lubiprostone',
#   'semantic_types': [],
#   'tree_numbers': ['D10.251.355.325.050.500']},
#  {'mesh_id': 'D000068239',
#   'mesh_name': 'Prunus persica',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.859.937.500.625.750']},
#  {'mesh_id': 'D000068240',
#   'mesh_name': 'Data Anonymization',
#   'semantic_types': [],
#   'tree_numbers': ['H01.770.644.205',
#    'L01.224.134.500',
#    'N03.706.437.650.124.160',
#    'N04.452.910.200.500']},
#  {'mesh_id': 'D000068241',
#   'mesh_name': 'Personally Identifiable Information',
#   'semantic_types': [],
#   'tree_numbers': ['I01.880.604.583.080.660']},
#  {'mesh_id': 'D000068242',
#   'mesh_name': 'Prunus domestica',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.859.937.500.625.450']},
#  {'mesh_id': 'D000068256',
#   'mesh_name': 'Darbepoetin alfa',
#   'semantic_types': [],
#   'tree_numbers': ['D09.400.430.775.150.500', 'D12.776.395.240.150.500']},
#  {'mesh_id': 'D000068257',
#   'mesh_name': 'Efavirenz, Emtricitabine, Tenofovir Disoproxil Fumarate Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D02.705.429.906.125',
#    'D03.383.533.375',
#    'D03.383.742.680.245.500.600.125',
#    'D03.633.100.759.138.881.125',
#    'D26.310.375']},
#  {'mesh_id': 'D000068258',
#   'mesh_name': 'Bevacizumab',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.124.486.485.114.224.060.375',
#    'D12.776.124.790.651.114.224.060.438',
#    'D12.776.377.715.548.114.224.200.438']},
#  {'mesh_id': 'D000068276',
#   'mesh_name': 'Giraffes',
#   'semantic_types': [],
#   'tree_numbers': ['B01.050.150.900.649.313.500.380.443']},
#  {'mesh_id': 'D000068296',
#   'mesh_name': 'Risedronic Acid',
#   'semantic_types': [],
#   'tree_numbers': ['D02.705.429.500.872', 'D03.383.725.836']},
#  {'mesh_id': 'D000068297',
#   'mesh_name': 'Fluticasone-Salmeterol Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.291.057.750.500',
#    'D02.092.063.291.057.750.500',
#    'D02.092.471.683.061.750.500',
#    'D04.210.500.054.079.129.114.500',
#    'D26.310.438']},
#  {'mesh_id': 'D000068298',
#   'mesh_name': 'Fluticasone',
#   'semantic_types': [],
#   'tree_numbers': ['D04.210.500.054.079.129.114']},
#  {'mesh_id': 'D000068299',
#   'mesh_name': 'Salmeterol Xinafoate',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.291.057.750',
#    'D02.092.063.291.057.750',
#    'D02.092.471.683.061.750']},
#  {'mesh_id': 'D000068316',
#   'mesh_name': 'Parks, Recreational',
#   'semantic_types': [],
#   'tree_numbers': ['J03.925.680']},
#  {'mesh_id': 'D000068336',
#   'mesh_name': 'Warfare and Armed Conflicts',
#   'semantic_types': [],
#   'tree_numbers': ['I01.880.735.950']},
#  {'mesh_id': 'D000068337',
#   'mesh_name': 'Armed Conflicts',
#   'semantic_types': [],
#   'tree_numbers': ['I01.880.735.950.250']},
#  {'mesh_id': 'D000068338',
#   'mesh_name': 'Everolimus',
#   'semantic_types': [],
#   'tree_numbers': ['D02.540.505.760.500']},
#  {'mesh_id': 'D000068342',
#   'mesh_name': 'Aspirin, Dipyridamole Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D02.455.426.559.389.657.410.595.176.500',
#    'D03.383.742.175.500',
#    'D26.310.125']},
#  {'mesh_id': 'D000068356',
#   'mesh_name': 'Self-Control',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.813.595']},
#  {'mesh_id': 'D000068357',
#   'mesh_name': 'Saline Waters',
#   'semantic_types': [],
#   'tree_numbers': ['G16.500.275.725']},
#  {'mesh_id': 'D000068376',
#   'mesh_name': 'Compassion Fatigue',
#   'semantic_types': [],
#   'tree_numbers': ['C23.888.369.500.500',
#    'F01.145.126.937.500',
#    'F01.145.126.990.734.500',
#    'F02.830.900.666.750']},
#  {'mesh_id': 'D000068377',
#   'mesh_name': 'Plantaginaceae',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.583.700']},
#  {'mesh_id': 'D000068378',
#   'mesh_name': 'Lamiales',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.583']},
#  {'mesh_id': 'D000068397',
#   'mesh_name': 'Clinical Study',
#   'semantic_types': [],
#   'tree_numbers': ['V03.175']},
#  {'mesh_id': 'D000068436',
#   'mesh_name': 'Surgical Clearance',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.505']},
#  {'mesh_id': 'D000068437',
#   'mesh_name': 'Pemetrexed',
#   'semantic_types': [],
#   'tree_numbers': ['D03.633.100.759.758.399.454.650',
#    'D12.125.067.625.525',
#    'D12.125.119.409.525']},
#  {'mesh_id': 'D000068438',
#   'mesh_name': 'Brimonidine Tartrate',
#   'semantic_types': [],
#   'tree_numbers': ['D03.633.100.857.070']},
#  {'mesh_id': 'D000068456',
#   'mesh_name': 'Clinical Studies as Topic',
#   'semantic_types': [],
#   'tree_numbers': ['E05.318.372.250',
#    'N05.715.360.330.250',
#    'N06.850.520.450.250']},
#  {'mesh_id': 'D000068476',
#   'mesh_name': 'Beijing',
#   'semantic_types': [],
#   'tree_numbers': ['Z01.252.474.164.225', 'Z01.433.114']},
#  {'mesh_id': 'D000068516',
#   'mesh_name': 'African Union',
#   'semantic_types': [],
#   'tree_numbers': ['I01.615.500.125', 'N03.540.089']},
#  {'mesh_id': 'D000068536',
#   'mesh_name': 'Firmicutes',
#   'semantic_types': [],
#   'tree_numbers': ['B03.353']},
#  {'mesh_id': 'D000068538',
#   'mesh_name': 'Dutasteride',
#   'semantic_types': [],
#   'tree_numbers': ['D04.210.500.925.100.125']},
#  {'mesh_id': 'D000068543',
#   'mesh_name': 'Calceolariaceae',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.583.190']},
#  {'mesh_id': 'D000068556',
#   'mesh_name': 'Interferon beta-1a',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.276.374.440.890.275.500',
#    'D12.776.467.374.440.890.275.500',
#    'D23.529.374.440.890.275.500']},
#  {'mesh_id': 'D000068557',
#   'mesh_name': 'Olmesartan Medoxomil',
#   'semantic_types': [],
#   'tree_numbers': ['D03.383.129.308.674', 'D03.383.129.617.584']},
#  {'mesh_id': 'D000068558',
#   'mesh_name': 'Amlodipine Besylate, Olmesartan Medoxomil Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D03.383.129.308.674.500',
#    'D03.383.129.617.584.500',
#    'D03.383.725.203.065.500',
#    'D26.310.063']},
#  {'mesh_id': 'D000068576',
#   'mesh_name': 'Interferon beta-1b',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.276.374.440.890.275.750',
#    'D12.776.467.374.440.890.275.750',
#    'D23.529.374.440.890.275.750']},
#  {'mesh_id': 'D000068577',
#   'mesh_name': 'Nebivolol',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.291.491',
#    'D02.092.063.291.503',
#    'D03.383.663.283.755',
#    'D03.633.100.150.755']},
#  {'mesh_id': 'D000068579',
#   'mesh_name': 'Celecoxib',
#   'semantic_types': [],
#   'tree_numbers': ['D02.065.884.060.020',
#    'D02.455.426.559.389.085.020',
#    'D02.886.590.700.090.020',
#    'D02.886.590.700.247',
#    'D03.383.129.539.160']},
#  {'mesh_id': 'D000068580',
#   'mesh_name': 'Varenicline',
#   'semantic_types': [],
#   'tree_numbers': ['D03.633.100.079.900', 'D03.633.100.857.942']},
#  {'mesh_id': 'D000068581',
#   'mesh_name': 'Tadalafil',
#   'semantic_types': [],
#   'tree_numbers': ['D03.383.725.150.500',
#    'D03.633.100.473.402.111.500',
#    'D03.633.300.154.672']},
#  {'mesh_id': 'D000068582',
#   'mesh_name': 'Certolizumab Pegol',
#   'semantic_types': [],
#   'tree_numbers': ['D05.750.741.125',
#    'D12.644.541.500.650.250',
#    'D12.776.124.486.485.114.224.060.500',
#    'D12.776.124.486.485.680.650.250',
#    'D12.776.124.790.651.114.224.060.500',
#    'D12.776.124.790.651.680.650.250',
#    'D12.776.377.715.548.114.224.200.500',
#    'D12.776.377.715.548.680.650.250']},
#  {'mesh_id': 'D000068597',
#   'mesh_name': 'Censorship, Research',
#   'semantic_types': [],
#   'tree_numbers': ['I01.880.604.238',
#    'K01.752.566.479.173.200',
#    'N05.350.670.250']},
#  {'mesh_id': 'D000068598',
#   'mesh_name': 'Data Accuracy',
#   'semantic_types': [],
#   'tree_numbers': ['E05.318.308.028',
#    'E05.318.370.725.250',
#    'L01.399.250.202',
#    'N05.715.360.300.202',
#    'N05.715.360.325.685.250']},
#  {'mesh_id': 'D000068599',
#   'mesh_name': 'Brimonidine Tartrate, Timolol Maleate Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.624.915.500',
#    'D02.033.755.624.915.500',
#    'D02.092.063.624.915.500',
#    'D02.886.675.867.768.500',
#    'D03.383.129.708.867.768.500',
#    'D03.633.100.857.070.500',
#    'D26.310.312']},
#  {'mesh_id': 'D000068600',
#   'mesh_name': 'Albuterol, Ipratropium Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.291.057.125',
#    'D02.092.063.291.057.125',
#    'D02.092.471.683.061.125',
#    'D02.145.074.722.229.400.500',
#    'D03.132.760.180.572.400.500',
#    'D03.132.889.180.648.400.500',
#    'D03.605.084.500.722.229.400.500',
#    'D03.605.869.229.400.500',
#    'D26.310.344']},
#  {'mesh_id': 'D000068601',
#   'mesh_name': 'Dual Use Research',
#   'semantic_types': [],
#   'tree_numbers': ['H01.770.644.217']},
#  {'mesh_id': 'D000068616',
#   'mesh_name': 'Professionalism',
#   'semantic_types': [],
#   'tree_numbers': ['K01.752.566.479.171.566', 'N05.350.340.581']},
#  {'mesh_id': 'D000068617',
#   'mesh_name': 'Genetic Background',
#   'semantic_types': [],
#   'tree_numbers': ['G05.346']},
#  {'mesh_id': 'D000068618',
#   'mesh_name': 'Selective Breeding',
#   'semantic_types': [],
#   'tree_numbers': ['E05.820.150.760', 'G05.090.701']},
#  {'mesh_id': 'D000068636',
#   'mesh_name': 'Legendary Creatures',
#   'semantic_types': [],
#   'tree_numbers': ['I01.076.201.450.515.500']},
#  {'mesh_id': 'D000068656',
#   'mesh_name': 'Mometasone Furoate',
#   'semantic_types': [],
#   'tree_numbers': ['D04.210.500.745.432.719.526']},
#  {'mesh_id': 'D000068676',
#   'mesh_name': 'Fallopia multiflora',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.825.359.590']},
#  {'mesh_id': 'D000068677',
#   'mesh_name': 'Sildenafil Citrate',
#   'semantic_types': [],
#   'tree_numbers': ['D02.065.884.675',
#    'D02.886.590.700.675',
#    'D03.383.606.854',
#    'D03.633.100.759.824']},
#  {'mesh_id': 'D000068678',
#   'mesh_name': 'Emtricitabine, Rilpivirine, Tenofovir Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D02.626.809.500',
#    'D02.705.429.906.500',
#    'D03.383.742.680.245.500.600.500',
#    'D03.383.742.755.500',
#    'D03.633.100.759.138.881.500',
#    'D26.310.407']},
#  {'mesh_id': 'D000068679',
#   'mesh_name': 'Emtricitabine',
#   'semantic_types': [],
#   'tree_numbers': ['D03.383.742.680.245.500.600',
#    'D13.570.230.329.525',
#    'D13.570.685.245.500.600']},
#  {'mesh_id': 'D000068696',
#   'mesh_name': 'Rilpivirine',
#   'semantic_types': [],
#   'tree_numbers': ['D02.626.809', 'D03.383.742.755']},
#  {'mesh_id': 'D000068698',
#   'mesh_name': 'Tenofovir',
#   'semantic_types': [],
#   'tree_numbers': ['D02.705.429.906', 'D03.633.100.759.138.881']},
#  {'mesh_id': 'D000068717',
#   'mesh_name': 'Glatiramer Acetate',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.219']},
#  {'mesh_id': 'D000068718',
#   'mesh_name': 'Rosuvastatin Calcium',
#   'semantic_types': [],
#   'tree_numbers': ['D02.065.884.650',
#    'D02.455.526.510.432.500',
#    'D02.886.590.700.650',
#    'D03.383.742.775']},
#  {'mesh_id': 'D000068736',
#   'mesh_name': 'Duloxetine Hydrochloride',
#   'semantic_types': [],
#   'tree_numbers': ['D02.886.778.260', 'D03.383.903.260']},
#  {'mesh_id': 'D000068737',
#   'mesh_name': 'Tolterodine Tartrate',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.624.706.750',
#    'D02.033.755.624.706.750',
#    'D02.092.063.624.706.800',
#    'D02.455.426.559.389.115.900',
#    'D02.455.426.559.389.657.239.756']},
#  {'mesh_id': 'D000068756',
#   'mesh_name': 'Valsartan',
#   'semantic_types': [],
#   'tree_numbers': ['D03.383.129.617.850',
#    'D12.125.070.950.550',
#    'D12.125.142.930.500']},
#  {'mesh_id': 'D000068757',
#   'mesh_name': 'Ononis',
#   'semantic_types': [],
#   'tree_numbers': ['B01.875.800.575.912.250.401.604']},
#  {'mesh_id': 'D000068758',
#   'mesh_name': 'Mometasone Furoate, Formoterol Fumarate Drug Combination',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.291.425.500',
#    'D02.092.063.291.425.500',
#    'D04.210.500.745.432.719.526.500',
#    'D26.310.469']},
#  {'mesh_id': 'D000068759',
#   'mesh_name': 'Formoterol Fumarate',
#   'semantic_types': [],
#   'tree_numbers': ['D02.033.100.291.425', 'D02.092.063.291.425']},
#  {'mesh_id': 'D000068760',
#   'mesh_name': 'Serotonin and Noradrenaline Reuptake Inhibitors',
#   'semantic_types': [],
#   'tree_numbers': ['D27.505.519.562.437.693',
#    'D27.505.519.625.600.693',
#    'D27.505.696.577.600.693']},
#  {'mesh_id': 'D000068776',
#   'mesh_name': 'Sleep Aids, Pharmaceutical',
#   'semantic_types': [],
# ...
#  {'mesh_id': 'D000072020',
#   'mesh_name': 'Synthetic Lethal Mutations',
#   'semantic_types': [],
#   'tree_numbers': ['G05.365.590.917']},
#  {'mesh_id': 'D000072036',
#   'mesh_name': 'Prophylactic Mastectomy',
#   'semantic_types': [],
#   'tree_numbers': ['E04.466.911', 'E04.625.500']},
#  {'mesh_id': 'D000072038',
#   'mesh_name': 'Cardiac Rehabilitation',
#   'semantic_types': [],
#   'tree_numbers': ['E02.760.169.063.500.185',
#    'E02.831.185',
#    'H02.403.680.600.250',
#    'N02.421.784.244']},
#  {'mesh_id': 'D000072039',
#   'mesh_name': 'Fracture Dislocation',
#   'semantic_types': [],
#   'tree_numbers': ['C05.550.518.336', 'C26.289.336', 'C26.404.026']},
#  {'mesh_id': 'D000072040',
#   'mesh_name': 'Apolipoprotein A-V',
#   'semantic_types': [],
#   'tree_numbers': ['D10.532.091.200.575',
#    'D12.776.070.400.200.575',
#    'D12.776.521.120.200.575']},
#  {'mesh_id': 'D000072041',
#   'mesh_name': 'PAX3 Transcription Factor',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.260.645.782', 'D12.776.930.700.782']},
#  {'mesh_id': 'D000072042',
#   'mesh_name': 'Salter-Harris Fractures',
#   'semantic_types': [],
#   'tree_numbers': ['C05.550.518.336.875',
#    'C26.289.336.875',
#    'C26.404.026.500']},
#  {'mesh_id': 'D000072056',
#   'mesh_name': 'Transcription Factor HES-1',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.260.103.844', 'D12.776.930.125.844']},
#  {'mesh_id': 'D000072077',
#   'mesh_name': 'Anesthetists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.140', 'N02.360.140']},
#  {'mesh_id': 'D000072078',
#   'mesh_name': 'Positron Emission Tomography Computed Tomography',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.350.350.800.700.500',
#    'E01.370.350.350.810.645',
#    'E01.370.350.567.500',
#    'E01.370.350.600.350.700.810.490',
#    'E01.370.350.600.350.800.399.500',
#    'E01.370.350.700.700.810.645',
#    'E01.370.350.700.810.810.723',
#    'E01.370.350.710.800.399.500',
#    'E01.370.350.825.800.399.500',
#    'E01.370.350.825.810.810.700',
#    'E01.370.384.730.800.399.500']},
#  {'mesh_id': 'D000072079',
#   'mesh_name': 'Patched Receptors',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.058', 'D12.776.624.776.633']},
#  {'mesh_id': 'D000072080',
#   'mesh_name': 'Anesthesiologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.140.040',
#    'M01.526.485.810.040',
#    'N02.360.140.040',
#    'N02.360.810.040']},
#  {'mesh_id': 'D000072081',
#   'mesh_name': 'Patched-1 Receptor',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.058.500', 'D12.776.624.776.633.500']},
#  {'mesh_id': 'D000072082',
#   'mesh_name': 'Patched-2 Receptor',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.058.750', 'D12.776.624.776.633.750']},
#  {'mesh_id': 'D000072085',
#   'mesh_name': 'Dermatologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.215', 'N02.360.810.215']},
#  {'mesh_id': 'D000072086',
#   'mesh_name': 'Smoothened Receptor',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.695.017.500',
#    'D12.776.543.750.850.500.500']},
#  {'mesh_id': 'D000072087',
#   'mesh_name': 'Occupational Therapists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.710', 'N02.360.710']},
#  {'mesh_id': 'D000072096',
#   'mesh_name': 'Cardiologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.128', 'N02.360.810.128']},
#  {'mesh_id': 'D000072097',
#   'mesh_name': 'Endocrinologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.303', 'N02.360.810.303']},
#  {'mesh_id': 'D000072098',
#   'mesh_name': 'Single Photon Emission Computed Tomography Computed Tomography',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.350.350.800.800.750',
#    'E01.370.350.350.810.723',
#    'E01.370.350.567.750',
#    'E01.370.350.600.350.700.810.645',
#    'E01.370.350.600.350.800.800.500',
#    'E01.370.350.700.700.810.723',
#    'E01.370.350.700.810.810.762',
#    'E01.370.350.710.800.800.750',
#    'E01.370.350.825.800.800.750',
#    'E01.370.350.825.810.810.750',
#    'E01.370.384.730.800.800.750']},
#  {'mesh_id': 'D000072099',
#   'mesh_name': 'Serrate-Jagged Proteins',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.276.930',
#    'D12.776.157.125.797',
#    'D12.776.543.800',
#    'D23.529.930']},
#  {'mesh_id': 'D000072100',
#   'mesh_name': 'Jagged-1 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.276.930.500',
#    'D12.776.157.125.797.500',
#    'D12.776.543.800.500',
#    'D23.529.930.500']},
#  {'mesh_id': 'D000072101',
#   'mesh_name': 'Jagged-2 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.276.930.750',
#    'D12.776.157.125.797.750',
#    'D12.776.543.800.750',
#    'D23.529.930.750']},
#  {'mesh_id': 'D000072102',
#   'mesh_name': 'Gastroenterologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.438', 'N02.360.810.438']},
#  {'mesh_id': 'D000072103',
#   'mesh_name': 'Oncologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.699', 'N02.360.810.699']},
#  {'mesh_id': 'D000072104',
#   'mesh_name': 'Nephrologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.628', 'N02.360.810.628']},
#  {'mesh_id': 'D000072105',
#   'mesh_name': 'Superoxide Dismutase-1',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.682.881.500']},
#  {'mesh_id': 'D000072106',
#   'mesh_name': 'Pulmonologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.865', 'N02.360.810.865']},
#  {'mesh_id': 'D000072117',
#   'mesh_name': 'Counselors',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.225']},
#  {'mesh_id': 'D000072137',
#   'mesh_name': 'Vaping',
#   'semantic_types': [],
#   'tree_numbers': ['F01.145.805.500']},
#  {'mesh_id': 'D000072138',
#   'mesh_name': 'Mosquito Vectors',
#   'semantic_types': [],
#   'tree_numbers': ['N06.850.335.188.100.500.500',
#    'N06.850.520.203.375.100.500.500']},
#  {'mesh_id': 'D000072139',
#   'mesh_name': 'Giant Viruses',
#   'semantic_types': [],
#   'tree_numbers': ['B04.280.356']},
#  {'mesh_id': 'D000072140',
#   'mesh_name': 'Rheumatologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.888', 'N02.360.810.888']},
#  {'mesh_id': 'D000072141',
#   'mesh_name': 'Neurologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.652', 'N02.360.810.652']},
#  {'mesh_id': 'D000072142',
#   'mesh_name': 'Pathologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.746', 'N02.360.810.746']},
#  {'mesh_id': 'D000072143',
#   'mesh_name': 'Pediatricians',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.758', 'N02.360.810.758']},
#  {'mesh_id': 'D000072156',
#   'mesh_name': 'Neonatologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.758.500', 'N02.360.810.758.500']},
#  {'mesh_id': 'D000072157',
#   'mesh_name': 'Physiatrists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.764', 'N02.360.810.764']},
#  {'mesh_id': 'D000072158',
#   'mesh_name': 'Epidemiologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.353', 'N02.360.345']},
#  {'mesh_id': 'D000072159',
#   'mesh_name': 'Dynactin Complex',
#   'semantic_types': [],
#   'tree_numbers': ['D05.500.142',
#    'D12.776.220.600.450.150',
#    'D12.776.631.560.225']},
#  {'mesh_id': 'D000072160',
#   'mesh_name': 'Tumor Protein p73',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.260.885',
#    'D12.776.624.776.820',
#    'D12.776.660.912',
#    'D12.776.930.969']},
#  {'mesh_id': 'D000072161',
#   'mesh_name': 'Orthopedic Surgeons',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.910.875', 'N02.360.810.910.875']},
#  {'mesh_id': 'D000072162',
#   'mesh_name': 'Optometrists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.725', 'N02.360.725']},
#  {'mesh_id': 'D000072163',
#   'mesh_name': 'Ophthalmologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.705', 'N02.360.810.705']},
#  {'mesh_id': 'D000072176',
#   'mesh_name': 'Superconductivity',
#   'semantic_types': [],
#   'tree_numbers': ['G01.358.500.875']},
#  {'mesh_id': 'D000072177',
#   'mesh_name': 'Radiologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.877', 'N02.360.810.877']},
#  {'mesh_id': 'D000072178',
#   'mesh_name': 'Urologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.955', 'N02.360.810.955']},
#  {'mesh_id': 'D000072179',
#   'mesh_name': 'Interleukin-1 Receptor-Like 1 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.750.705.852.420.300.375']},
#  {'mesh_id': 'D000072180',
#   'mesh_name': 'Phosphoinositide Phosphatases',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.352.650.624']},
#  {'mesh_id': 'D000072181',
#   'mesh_name': 'Inositol Polyphosphate 5-Phosphatases',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.352.650.624.500']},
#  {'mesh_id': 'D000072182',
#   'mesh_name': 'Non-Medical Public and Private Facilities',
#   'semantic_types': [],
#   'tree_numbers': ['J03']},
#  {'mesh_id': 'D000072183',
#   'mesh_name': 'Phosphatidylinositol-3,4,5-Trisphosphate 5-Phosphatases',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.352.650.624.750']},
#  {'mesh_id': 'D000072184',
#   'mesh_name': 'Nurse Specialists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.650.648', 'N02.360.650.648']},
#  {'mesh_id': 'D000072196',
#   'mesh_name': 'Fertilins',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.656.675.374.102.750',
#    'D09.400.430.500.750',
#    'D09.400.430.890.331',
#    'D12.776.395.033.750',
#    'D12.776.395.550.331']},
#  {'mesh_id': 'D000072197',
#   'mesh_name': 'ADAM10 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.656.675.374.102.250',
#    'D09.400.430.500.250',
#    'D12.776.395.033.250']},
#  {'mesh_id': 'D000072198',
#   'mesh_name': 'ADAM17 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.656.675.374.102.375',
#    'D09.400.430.500.375',
#    'D12.776.395.033.375']},
#  {'mesh_id': 'D000072199',
#   'mesh_name': 'ADAM12 Protein',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.656.675.374.102.125',
#    'D09.400.430.500.125',
#    'D12.776.395.033.125']},
#  {'mesh_id': 'D000072200',
#   'mesh_name': 'Ku Autoantigen',
#   'semantic_types': [],
#   'tree_numbers': ['D08.811.277.040.025.159.155',
#    'D08.811.399.340.155',
#    'D12.776.157.687.493',
#    'D12.776.260.525',
#    'D12.776.660.625.625',
#    'D12.776.660.720.493',
#    'D23.050.290.625']},
#  {'mesh_id': 'D000072216',
#   'mesh_name': 'Zona Pellucida Glycoproteins',
#   'semantic_types': [],
#   'tree_numbers': ['D09.400.430.890.995',
#    'D12.776.290.906',
#    'D12.776.395.550.995',
#    'D12.776.543.550.995',
#    'D12.776.543.750.981']},
#  {'mesh_id': 'D000072218',
#   'mesh_name': 'Endodontists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.330.330.397', 'N02.360.330.330.397']},
#  {'mesh_id': 'D000072219',
#   'mesh_name': 'Geriatricians',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.533', 'N02.360.810.533']},
#  {'mesh_id': 'D000072220',
#   'mesh_name': 'Otolaryngologists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.734', 'N02.360.810.734']},
#  {'mesh_id': 'D000072221',
#   'mesh_name': 'Nurses, Neonatal',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.650.648.940.500', 'N02.360.650.648.940.500']},
#  {'mesh_id': 'D000072222',
#   'mesh_name': 'Nurses, Pediatric',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.650.648.940', 'N02.360.650.648.940']},
#  {'mesh_id': 'D000072223',
#   'mesh_name': 'Allergists',
#   'semantic_types': [],
#   'tree_numbers': ['M01.526.485.810.020', 'N02.360.810.020']},
#  {'mesh_id': 'D000072224',
#   'mesh_name': 'Bcl-2-Like Protein 11',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.360.075.323',
#    'D12.776.476.075.323',
#    'D12.776.543.116',
#    'D12.776.624.664.700.025']},
#  {'mesh_id': 'D000072226',
#   'mesh_name': 'Computed Tomography Angiography',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.350.350.810.335',
#    'E01.370.350.567.250',
#    'E01.370.350.600.350.700.810.335',
#    'E01.370.350.700.700.810.335',
#    'E01.370.350.700.810.810.568',
#    'E01.370.350.825.810.810.499']},
#  {'mesh_id': 'D000072227',
#   'mesh_name': 'Shoulder Prosthesis',
#   'semantic_types': [],
#   'tree_numbers': ['E07.695.400.852']},
#  {'mesh_id': 'D000072228',
#   'mesh_name': 'Arthroplasty, Replacement, Shoulder',
#   'semantic_types': [],
#   'tree_numbers': ['E04.555.110.110.299',
#    'E04.617.101.110.299',
#    'E04.650.110.299']},
#  {'mesh_id': 'D000072229',
#   'mesh_name': 'Posterior Cruciate Ligament Reconstruction',
#   'semantic_types': [],
#   'tree_numbers': ['E02.718.688', 'E04.555.110.557', 'E04.617.101.557']},
#  {'mesh_id': 'D000072230',
#   'mesh_name': 'Sustained Virologic Response',
#   'semantic_types': [],
#   'tree_numbers': ['E01.789.800.570',
#    'N04.761.559.590.800.665',
#    'N05.715.360.575.575.800.665']},
#  {'mesh_id': 'D000072231',
#   'mesh_name': 'In Vivo Dosimetry',
#   'semantic_types': [],
#   'tree_numbers': ['E05.799.638.511']},
#  {'mesh_id': 'D000072232',
#   'mesh_name': 'Radiation Dosimeters',
#   'semantic_types': [],
#   'tree_numbers': ['E07.710.725']},
#  {'mesh_id': 'D000072233',
#   'mesh_name': 'Homer Scaffolding Proteins',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.476.024.381']},
#  {'mesh_id': 'D000072234',
#   'mesh_name': 'Donor Conception',
#   'semantic_types': [],
#   'tree_numbers': ['E02.875.800.250', 'E05.820.800.250']},
#  {'mesh_id': 'D000072235',
#   'mesh_name': 'Mating Factor',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.368', 'D23.641.200']},
#  {'mesh_id': 'D000072236',
#   'mesh_name': 'Methyl-Accepting Chemotaxis Proteins',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.360.420',
#    'D12.776.097.533',
#    'D12.776.476.420',
#    'D12.776.543.750.054']},
#  {'mesh_id': 'D000072237',
#   'mesh_name': 'ERG1 Potassium Channel',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.530.400.600.900.249.500',
#    'D12.776.543.550.450.750.900.249.500',
#    'D12.776.543.585.400.750.900.249.500']},
#  {'mesh_id': 'D000072257',
#   'mesh_name': 'Oxygen Radical Absorbance Capacity',
#   'semantic_types': [],
#   'tree_numbers': ['E05.657']},
#  {'mesh_id': 'D000072258',
#   'mesh_name': 'Tumor Hypoxia',
#   'semantic_types': [],
#   'tree_numbers': ['G03.197.300.500', 'G04.270.300.500']},
#  {'mesh_id': 'D000072259',
#   'mesh_name': 'Connexin 26',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.543.585.250.100']},
#  {'mesh_id': 'D000072260',
#   'mesh_name': 'RNA Splicing Factors',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.157.725.829', 'D12.776.664.962.829']},
#  {'mesh_id': 'D000072261',
#   'mesh_name': 'Dishevelled Proteins',
#   'semantic_types': [],
#   'tree_numbers': ['D12.644.360.024.288',
#    'D12.776.157.057.028',
#    'D12.776.476.024.330']},
#  {'mesh_id': 'D000072263',
#   'mesh_name': 'Private Facilities',
#   'semantic_types': [],
#   'tree_numbers': ['J03.700']},
#  {'mesh_id': 'D000072264',
#   'mesh_name': 'Sports and Recreational Facilities',
#   'semantic_types': [],
#   'tree_numbers': ['J03.925']},
#  {'mesh_id': 'D000072277',
#   'mesh_name': 'Maximal Respiratory Pressures',
#   'semantic_types': [],
#   'tree_numbers': ['E01.370.386.700.550']},
#  {'mesh_id': 'D000072278',
#   'mesh_name': 'Forkhead Box Protein M1',
#   'semantic_types': [],
#   'tree_numbers': ['D12.776.260.950.249.063', 'D12.776.930.977.249.063']},
#  {'mesh_id': 'D000072280',
#   'mesh_name': 'Bacteria, Thermoduric',
#   'semantic_types': [],
#   'tree_numbers': ['B03.135']},
#  {'mesh_id': 'D000072281',
#   'mesh_name': 'Lymphadenopathy',
#   'semantic_types': [],
#   'tree_numbers': ['C15.604.338']},
#  {'mesh_id': 'D000072282',
#   'mesh_name': 'Extraintestinal Pathogenic Escherichia coli',
#   'semantic_types': [],
#   'tree_numbers': ['B03.440.450.425.325.300.580',
#    'B03.660.250.150.180.100.580']},
#  {'mesh_id': 'D000072283',
#   'mesh_name': 'A549 Cells',
#   'semantic_types': [],
#   'tree_numbers': ['A11.251.210.190.080',
#    'A11.251.860.180.080',
#    'A11.436.054']},
#  {'mesh_id': 'D000072296',
#   'mesh_name': 'Bathroom Equipment',
#   'semantic_types': [],
#   'tree_numbers': ['E07.108']},
#  {'mesh_id': 'D000072316',
#   'mesh_name': 'Dioxins and Dioxin-like Compounds',
#   'semantic_types': [],
#   'tree_numbers': ['D02.309']},
#  {'mesh_id': 'D000072317',
#   'mesh_name': 'Polychlorinated Dibenzodioxins',
#   'semantic_types': [],
#   'tree_numbers': ['D02.309.500.450', 'D03.633.300.786']},
#  ...]

# %%
# Determine ontology parents
tree_number_to_id = {tn: term['mesh_id'] for term in terms for tn in term['tree_numbers']}

for term in terms:
    parents = set()
    for tree_number in term['tree_numbers']:
        try:
            parent_tn, self_tn = tree_number.rsplit('.', 1)
            parents.add(tree_number_to_id[parent_tn])
        except ValueError:
            pass
    term['parents'] = list(parents)

# %%
term
# Out:
# {'mesh_id': 'D066331',
#  'mesh_name': 'Laser-Evoked Potentials',
#  'semantic_types': [],
#  'tree_numbers': ['G07.265.216.500.400.500', 'G11.561.200.500.400.500'],
#  'parents': ['D005073']}

# %%
path = os.path.join(download_dir, 'mesh.json')
with open(path, 'w') as write_file:
    json.dump(terms, write_file, indent=2)

# %%
# Create a newtorkx directed graph represented mesh
network = networkx.DiGraph()

# add nodes
for term in terms:
    network.add_node(term['mesh_id'], name=term['mesh_name'])

# add edges
for term in terms:
    for parent in term['parents']:
        network.add_edge(parent, term['mesh_id'])

#assert networkx.is_directed_acyclic_graph(network)

networkx.write_gexf(network, os.path.join(download_dir, 'ontology.gexf.gz'))

# %%
# Read mesh
path = os.path.join(download_dir, 'mesh.json')
with open(path) as read_file:
    mesh = json.load(read_file)

mesh_df = pandas.DataFrame.from_dict(mesh)[['mesh_id', 'mesh_name']]
mesh_df.to_csv(os.path.join(download_dir, 'terms.tsv'), sep='\t', index=False)
mesh_df
# Out:
#        mesh_id                    mesh_name
# 0      D000001                   Calcimycin
# 1      D000002                      Temefos
# 2      D000003                    Abattoirs
# 3      D000004       Abbreviations as Topic
# 4      D000005                      Abdomen
# ...        ...                          ...
# 30759  D066310               Digital Divide
# 30760  D066328             Ventral Striatum
# 30761  D066329           Protein Aggregates
# 30762  D066330  Printing, Three-Dimensional
# 30763  D066331      Laser-Evoked Potentials
#
# [30764 rows x 2 columns]

# %%
# Extract (mesh_id, mesh_tree_number) pairs
rows = []
for term in mesh:
    mesh_id = term['mesh_id']
    mesh_name = term['mesh_name']
    for tree_number in term['tree_numbers']:
        rows.append([mesh_id, mesh_name, tree_number])

tn_df = pandas.DataFrame(rows, columns=['mesh_id', 'mesh_name', 'mesh_tree_number'])
tn_df.to_csv(os.path.join(download_dir, 'tree-numbers.tsv'), sep='\t', index=False)
tn_df
# Out:
#        mesh_id                    mesh_name         mesh_tree_number
# 0      D000001                   Calcimycin      D02.355.291.933.125
# 1      D000001                   Calcimycin      D02.540.576.625.125
# 2      D000001                   Calcimycin      D03.633.100.221.173
# 3      D000001                   Calcimycin      D04.345.241.654.125
# 4      D000001                   Calcimycin      D04.345.674.625.125
# ...        ...                          ...                      ...
# 64452  D066330  Printing, Three-Dimensional              J01.897.564
# 64453  D066330  Printing, Three-Dimensional      L01.224.108.150.500
# 64454  D066330  Printing, Three-Dimensional      L01.296.110.150.500
# 64455  D066331      Laser-Evoked Potentials  G07.265.216.500.400.500
# 64456  D066331      Laser-Evoked Potentials  G11.561.200.500.400.500
#
# [64457 rows x 3 columns]

# %% [markdown]
# # Diseases

# %%
def is_human_disease(tn):
    """Given a tree number, return whether the heirarchical path suggests a human disease."""
    # F03 (mental disorders)
    if tn.startswith('F03'):
        return True
    # C01 though C21 and C24 -- C26
    for i in list(range(1, 22)) + ['C24', 'C25', 'C26']:
        if tn.startswith('C' + str(i).zfill(2)):
            return True
    # C23 exlcuding C23.888 (Symptoms and Signs)
    if tn.startswith('C23') and not tn.startswith('C23.888'):
        return True
    return False

# %%
diseases = {term['mesh_id'] for term in terms if any(map(is_human_disease, term['tree_numbers']))}
len(diseases)
# Out:
# 4851

# %% [markdown]
# # Symptoms

# %%
# Read HSDN symptoms
url = 'https://raw.githubusercontent.com/LABrueggs/HSDN/master/Symptom-Occurence-Output.tsv' #https://github.com/LeoBman/HSDN/tree/master?tab=readme-ov-file
hsdn_symptom_df = pandas.read_table(url, index_col=0)
hsdn_symptoms = hsdn_symptom_df['MeSH Symptom ID']

# %%
# find MeSH symptoms
symptoms = networkx.descendants(network, 'D012816') # signs and symptoms https://www.ncbi.nlm.nih.gov/mesh/68012816 
symptom_df = mesh_df[mesh_df.mesh_id.isin(symptoms)]
pandas.options.mode.chained_assignment = None
symptom_df['in_hsdn'] = symptom_df.mesh_id.isin(hsdn_symptoms).astype(int)
symptom_df.to_csv(os.path.join(download_dir, 'symptoms.tsv'), index=False, sep='\t')
symptom_df
# Out:
#           mesh_id                             mesh_name  in_hsdn
# 5         D000006                        Abdomen, Acute        1
# 131    D000067329         Obesity, Metabolically Benign        0
# 141    D000067404         Social Communication Disorder        0
# 147    D000067454      Childhood-Onset Fluency Disorder        0
# 168    D000067559            Specific Learning Disorder        0
# ...           ...                                   ...      ...
# 30548     D065634              Cerebrospinal Fluid Leak        0
# 30549     D065635  Benign Paroxysmal Positional Vertigo        0
# 30645     D065906                       Hyperlactatemia        0
# 30685     D066190                           Allesthesia        0
# 30694     D066229                 Speech Sound Disorder        0
#
# [505 rows x 3 columns]

# %%
sum(symptom_df.in_hsdn)
# Out:
# 317

# %%
#compare with hetionet version  438 mesh terms 
symptom_hetionet = pandas.read_table('https://raw.githubusercontent.com/dhimmel/mesh/gh-pages/data/symptoms.tsv') #, index_col=0
symptom_hetionet
# Out:
#                                     mesh_name  in_hsdn
# mesh_id
# D000006                        Abdomen, Acute        1
# D000270                         Adie Syndrome        0
# D000326                  Adrenoleukodystrophy        0
# D000334                             Aerophagy        1
# D000370                               Ageusia        1
# ...                                       ...      ...
# D064250            Hypertriglyceridemic Waist        0
# D065634              Cerebrospinal Fluid Leak        0
# D065635  Benign Paroxysmal Positional Vertigo        0
# D065906                       Hyperlactatemia        0
# D066190                           Allesthesia        0
#
# [438 rows x 2 columns]

# %% [markdown]
# # Side Effects

# %%
side_effects = networkx.descendants(network, 'D064420') # Drug-Related Side Effects and Adverse Reactions
side_effect_df = mesh_df[mesh_df.mesh_id.isin(side_effects)]
len(side_effect_df)
